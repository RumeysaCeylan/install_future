# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/install-future-program-ankara-hackathon/sample_submission.csv
# /kaggle/input/install-future-program-ankara-hackathon/train.csv
# /kaggle/input/install-future-program-ankara-hackathon/test.csv

# %%
data = pd.read_csv("/kaggle/input/install-future-program-ankara-hackathon/train.csv")
test_data=pd.read_csv("/kaggle/input/install-future-program-ankara-hackathon/test.csv")

# %%
data.head()
# Out:
#                     DATETIME     SERVER     CPU  CPULOAD
# 0  2020-03-24 00:00:00+03:00  CIHAZ_301   CPU-0     3.88
# 1  2020-03-24 00:00:00+03:00  CIHAZ_301   CPU-1    11.33
# 2  2020-03-24 00:00:00+03:00  CIHAZ_301  CPU-10     5.31
# 3  2020-03-24 00:00:00+03:00  CIHAZ_301  CPU-11     5.25
# 4  2020-03-24 00:00:00+03:00  CIHAZ_301  CPU-12     0.28

# %%
data.tail()
# Out:
#                          DATETIME     SERVER    CPU  CPULOAD
# 312691  2020-05-30 23:45:00+03:00  CIHAZ_305  CPU-5    16.17
# 312692  2020-05-30 23:45:00+03:00  CIHAZ_305  CPU-6    16.02
# 312693  2020-05-30 23:45:00+03:00  CIHAZ_305  CPU-7    14.14
# 312694  2020-05-30 23:45:00+03:00  CIHAZ_305  CPU-8    15.42
# 312695  2020-05-30 23:45:00+03:00  CIHAZ_305  CPU-9    13.30

# %%
test_data.head()
# Out:
#    index                   DATETIME     SERVER     CPU
# 0      0  2020-05-31 00:00:00+03:00  CIHAZ_301   CPU-0
# 1      1  2020-05-31 00:00:00+03:00  CIHAZ_301   CPU-1
# 2      2  2020-05-31 00:00:00+03:00  CIHAZ_301  CPU-10
# 3      3  2020-05-31 00:00:00+03:00  CIHAZ_301  CPU-11
# 4      4  2020-05-31 00:00:00+03:00  CIHAZ_301  CPU-12

# %%
test_data.tail()
# Out:
#       index                   DATETIME     SERVER    CPU
# 4603   4603  2020-05-31 23:45:00+03:00  CIHAZ_305  CPU-5
# 4604   4604  2020-05-31 23:45:00+03:00  CIHAZ_305  CPU-6
# 4605   4605  2020-05-31 23:45:00+03:00  CIHAZ_305  CPU-7
# 4606   4606  2020-05-31 23:45:00+03:00  CIHAZ_305  CPU-8
# 4607   4607  2020-05-31 23:45:00+03:00  CIHAZ_305  CPU-9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312696 entries, 0 to 312695
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   DATETIME  312696 non-null  object
#  1   SERVER    312696 non-null  object
#  2   CPU       312696 non-null  object
#  3   CPULOAD   312696 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 9.5+ MB

# %%
data.describe()
# Out:
#              CPULOAD
# count  312696.000000
# mean       10.283954
# std         9.904820
# min         0.060000
# 25%         2.050000
# 50%         6.820000
# 75%        16.040000
# max        68.840000

# %%
data.corr(numeric_only=True)
# Out:
#          CPULOAD
# CPULOAD      1.0

# %%
import matplotlib.pyplot as plt

# %%
data.dtypes
# Out:
# DATETIME     object
# SERVER       object
# CPU          object
# CPULOAD     float64
# dtype: object

# %%
data.columns
# Out:
# Index(['DATETIME', 'SERVER', 'CPU', 'CPULOAD'], dtype='object')

# %%
test_data.head()
# Out:
#    index                   DATETIME     SERVER     CPU
# 0      0  2020-05-31 00:00:00+03:00  CIHAZ_301   CPU-0
# 1      1  2020-05-31 00:00:00+03:00  CIHAZ_301   CPU-1
# 2      2  2020-05-31 00:00:00+03:00  CIHAZ_301  CPU-10
# 3      3  2020-05-31 00:00:00+03:00  CIHAZ_301  CPU-11
# 4      4  2020-05-31 00:00:00+03:00  CIHAZ_301  CPU-12

# %%
data.dtypes
# Out:
# DATETIME     object
# SERVER       object
# CPU          object
# CPULOAD     float64
# dtype: object

# %%
data.loc[(data['DATETIME'] > '2020-05-15 00:00:00') & (data['DATETIME'] < '2020-05-15 01:00:10')] \
    .plot(figsize=(15, 5), title='DATA')
plt.show()

# %%
train = data.loc[data['DATETIME'] < '2020-05-15']
test = data.loc[data['DATETIME'] >= '2020-05-15']

fig, ax = plt.subplots(figsize=(15, 5))
train.plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test.plot(ax=ax, label='Test Set')
ax.axvline('2020-05-15', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %%
data['DATETIME'] = pd.to_datetime(data['DATETIME'])

data['DATETIME'] = data['DATETIME'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
test_data['DATETIME'] = pd.to_datetime(test_data['DATETIME'])
test_data['DATETIME'] = test_data['DATETIME'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
import pandas as pd
from prophet import Prophet


predictions_df = pd.DataFrame()

for server in data['SERVER'].unique():
    for cpu in data[data['SERVER'] == server]['CPU'].unique():

        temp_df = data[(data['SERVER'] == server) & (data['CPU'] == cpu)].copy()
        temp_df = temp_df[['DATETIME', 'CPULOAD']] 
        temp_df.columns = ['ds', 'y']  

        model = Prophet(yearly_seasonality=True, weekly_seasonality=True, daily_seasonality=True)
        model.fit(temp_df)

        future = test_data[test_data['SERVER'] == server][['DATETIME']].copy()
        future.columns = ['ds']
        forecast = model.predict(future)

       
        forecast['SERVER'] = server  
        forecast['CPU'] = cpu
        predictions_df = pd.concat([predictions_df, forecast], ignore_index=True)
# Out:
# 11:52:47 - cmdstanpy - INFO - Chain [1] start processing
# 11:52:50 - cmdstanpy - INFO - Chain [1] done processing
# 11:52:52 - cmdstanpy - INFO - Chain [1] start processing
# 11:52:53 - cmdstanpy - INFO - Chain [1] done processing
# 11:52:55 - cmdstanpy - INFO - Chain [1] start processing
# 11:52:58 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:01 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:03 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:08 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:10 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:14 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:16 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:20 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:22 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:25 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:27 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:31 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:33 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:40 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:42 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:44 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:48 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:50 - cmdstanpy - INFO - Chain [1] start processing
# 11:53:53 - cmdstanpy - INFO - Chain [1] done processing
# 11:53:55 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:00 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:02 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:06 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:08 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:10 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:12 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:15 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:17 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:20 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:23 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:25 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:27 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:30 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:33 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:40 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:42 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:44 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:47 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:49 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:53 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:56 - cmdstanpy - INFO - Chain [1] start processing
# 11:54:57 - cmdstanpy - INFO - Chain [1] done processing
# 11:54:59 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:01 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:04 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:06 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:07 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:09 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:10 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:13 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:14 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:16 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:17 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:19 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:20 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:22 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:24 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:26 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:27 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:29 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:31 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:33 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:34 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:39 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:41 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:43 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:45 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:47 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:48 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:50 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:52 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:54 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:56 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:58 - cmdstanpy - INFO - Chain [1] done processing
# 11:56:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:56:01 - cmdstanpy - INFO - Chain [1] done processing
# 11:56:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:56:04 - cmdstanpy - INFO - Chain [1] done processing
# 11:56:06 - cmdstanpy - INFO - Chain [1] start processing
# 11:56:07 - cmdstanpy - INFO - Chain [1] done processing
# 11:56:09 - cmdstanpy - INFO - Chain [1] start processing
# 11:56:10 - cmdstanpy - INFO - Chain [1] done processing
# 11:56:12 - cmdstanpy - INFO - Chain [1] start processing
# 11:56:13 - cmdstanpy - INFO - Chain [1] done processing

# %%
import datetime
fig = model.plot(forecast)

plt.legend(['Actual', 'Prediction', 'Uncertainty interval'])
plt.show(x)

# %%
predictions_df.yhat
# Out:
# index
# 0        3.681693
# 1        3.277366
# 2        2.887223
# 3        2.514482
# 4        2.162223
#           ...
# 4603    20.953887
# 4604    20.048203
# 4605    19.122462
# 4606    18.194104
# 4607    17.281366
# Name: yhat, Length: 4608, dtype: float64

# %%
submission_df = predictions_df[['yhat']]
submission_df.index.name = 'index'
submission_df.columns = ['CPULOAD']
submission_df.to_csv('submission.csv', index=True)

# %%
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head())
# Out:
#                    ds       yhat  yhat_lower  yhat_upper
# 0 2020-05-31 00:00:00  12.645004    7.195505   17.533740
# 1 2020-05-31 00:15:00  11.761111    6.459630   17.064003
# 2 2020-05-31 00:30:00  10.943792    5.760761   15.738858
# 3 2020-05-31 00:45:00  10.204501    5.109614   15.697010
# 4 2020-05-31 01:00:00   9.550995    4.224486   14.544112

# %%
"""
import pandas as pd
from prophet import Prophet
from sklearn.metrics import mean_absolute_error


predictions_df = pd.DataFrame()

for server in data['SERVER'].unique():
    for cpu in data[data['SERVER'] == server]['CPU'].unique():

        temp_df = data[(data['SERVER'] == server) & (data['CPU'] == cpu)].copy()
        temp_df = temp_df[['DATETIME', 'CPULOAD']] 
        temp_df.columns = ['ds', 'y']  

        model = Prophet(yearly_seasonality=True, weekly_seasonality=True, daily_seasonality=True)
        model.fit(temp_df)

        future = test_data[test_data['SERVER'] == server][test_data['CPU'] == cpu][['DATETIME']].copy()
        future.columns = ['ds']
        forecast = model.predict(future)

       
        forecast['SERVER'] = server  
        forecast['CPU'] = cpu
        predictions_df = pd.concat([predictions_df, forecast], ignore_index=True)
mae=mean_absolute_error(temp_df['y'],forecast['yhat'])
print(mae)
"""
# Out:
# "\nimport pandas as pd\nfrom prophet import Prophet\nfrom sklearn.metrics import mean_absolute_error\n\n\npredictions_df = pd.DataFrame()\n\nfor server in data['SERVER'].unique():\n    for cpu in data[data['SERVER'] == server]['CPU'].unique():\n\n        temp_df = data[(data['SERVER'] == server) & (data['CPU'] == cpu)].copy()\n        temp_df = temp_df[['DATETIME', 'CPULOAD']] \n        temp_df.columns = ['ds', 'y']  \n\n        model = Prophet(yearly_seasonality=True, weekly_seasonality=True, daily_seasonality=True)\n        model.fit(temp_df)\n\n        future = test_data[test_data['SERVER'] == server][test_data['CPU'] == cpu][['DATETIME']].copy()\n        future.columns = ['ds']\n        forecast = model.predict(future)\n\n       \n        forecast['SERVER'] = server  \n        forecast['CPU'] = cpu\n        predictions_df = pd.concat([predictions_df, forecast], ignore_index=True)\nmae=mean_absolute_error(temp_df['y'],forecast['yhat'])\nprint(mae)\n"

# %%
"""
from sklearn.metrics import mean_absolute_error

grouped= data.groupby(['SERVER','GPU'])
MAEs=[]
predictions_df = pd.DataFrame()

for server in data['SERVER'].unique():
    for cpu in data[data['SERVER'] == server]['CPU'].unique():

        temp_df = data[(data['SERVER'] == server) & (data['CPU'] == cpu)].copy()
        temp_df = temp_df[['DATETIME', 'CPULOAD']] 
        temp_df.columns = ['ds', 'y']  

        model = Prophet(yearly_seasonality=True, weekly_seasonality=True, daily_seasonality=True)
        model.fit(temp_df)

        future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
        future.columns = ['ds']
        forecast_df = model.predict(future)
        forecast_df['fact'] = temp_df['y'].reset_index(drop = True)

       
        forecast_df['SERVER'] = server  
        forecast_df['CPU'] = cpu
        predictions_df = pd.concat([predictions_df, forecast_df], ignore_index=True)

"""
# Out:
# 11:26:55 - cmdstanpy - INFO - Chain [1] start processing
# 11:26:57 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:27:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:01 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:27:04 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:08 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:27:10 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:13 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:27:16 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:18 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:27:21 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:24 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:27:27 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:31 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:27:34 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:37 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:27:39 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:43 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:27:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:53 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:27:56 - cmdstanpy - INFO - Chain [1] start processing
# 11:27:58 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:28:01 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:03 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:28:06 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:08 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:28:11 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:16 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:28:19 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:22 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:28:25 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:27 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:28:30 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:33 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:28:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:39 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:28:42 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:44 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:28:47 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:50 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:28:53 - cmdstanpy - INFO - Chain [1] start processing
# 11:28:58 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:01 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:03 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:06 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:09 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:12 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:16 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:19 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:20 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:23 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:24 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:27 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:28 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:31 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:32 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:35 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:36 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:39 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:41 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:43 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:45 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:48 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:49 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:52 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:53 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:29:57 - cmdstanpy - INFO - Chain [1] start processing
# 11:29:58 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:00 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:02 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:06 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:09 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:10 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:13 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:15 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:18 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:20 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:22 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:24 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:27 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:28 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:31 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:33 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:37 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:40 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:40 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:43 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:44 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:47 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:48 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:51 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:52 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# 11:30:55 - cmdstanpy - INFO - Chain [1] start processing
# 11:30:56 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_32/1416962179.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   future = data[data['SERVER'] == server][data['CPU'] == cpu][['DATETIME']].copy()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[162], line 25
#      23         forecast_df['CPU'] = cpu
#      24         predictions_df = pd.concat([predictions_df, forecast_df], ignore_index=True)
# ---> 25 mae =  mean_absolute_error()
#
# TypeError: mean_absolute_error() missing 2 required positional arguments: 'y_true' and 'y_pred'

# %%
#predictions_df.head()

# %%
#forecasted = forecast_df[['ds','trend', 'yhat', 'yhat_lower', 'yhat_upper', 'fact']].copy()

# %%
#forecasted

# %%
"""
forecasted['anomaly']=0
forecasted[forecasted['fact']>forecasted['yhat_upper'],'anomaly']=1
forecasted[forecasted['fact']<forecasted['yhat_lower'],'anomaly']=-1
"""

# %%
#forecasted

# %%
"""


forecasted['importance'] = 0
forecasted.loc[forecasted['anomaly'] ==1, 'importance'] =(forecasted['fact'] - forecasted['yhat_upper'])/forecast['fact']
forecasted.loc[forecasted['anomaly'] ==-1, 'importance'] =(forecasted['yhat_lower'] - forecasted['fact'])/forecast['fact']
"""

# %%
#predictions_df.info()

# %%
"""
model.plot(forecast_df)  
forecast_df = forecast_df.rename(columns={'yhat': 'yhat_'+ server})
target = pd.merge(predictions_df, forecast_df.set_index('ds'), how='outer', left_index=True, right_index=True)
"""

# %%
"""
print(forecast_df[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head())
model.plot(forecast_df)
plt.xlabel('Time')
plt.ylabel('prediction')
plt.show()
"""

# %%
#fig2 = model.plot_components(forecast)

# %%
#forecast.head()

# %%
"""
start_date = '2020-05-15 00:00:00'
end_date = '2020-05-30 23:59:00'
filtered_data = data[(data['DATETIME'] >= start_date) & (data['DATETIME'] <= end_date)]

"""

# %% [markdown]
# ### average_loads = filtered_data.groupby(['SERVER', 'CPU'])['CPULOAD'].mean().reset_index()

# %%
"""
start_date = '2020-05-15 00:00:00'
end_date = '2020-05-30 23:59:00'
filtered_data = data[(data['DATETIME'] >= start_date) & (data['DATETIME'] <= end_date)]

"""

# %%
"""
threshold = average_loads['CPULOAD'].mean() + 3*average_loads['CPULOAD'].std()
anomalies = average_loads[average_loads['CPULOAD'] > threshold]
anomalies = anomalies.merge(filtered_data[['SERVER', 'CPU', 'DATETIME']], on=['SERVER', 'CPU'], how='left')

"""

# %%
"""
anomalies
"""
# Out:
# Empty DataFrame
# Columns: [CPULOAD, SERVER, CPU, DATETIME]
# Index: []

# %%
"""
import matplotlib.pyplot as plt

plt.scatter(filtered_data['DATETIME'], filtered_data['CPULOAD'], color='blue', label='Normal')
plt.scatter(anomalies['DATETIME'], anomalies['CPULOAD'], color='red', label='Anomaly')
plt.xlabel('Tarih')
plt.ylabel('CPULOAD')
plt.title('Nokta Grafiği - Anomaliler')
plt.legend()
plt.show()

"""

# %%
"""
data['residuals'] = temp_df['y'] - forecast_df['yhat']

# 1.45
threshold = data['residuals'].std() * 1.5
anomalies = data[data['residuals'].abs() > threshold]
"""
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[272], line 1
# ----> 1 data['residuals'] = forecast_df['y'] - forecast_df['yhat']
#       3 # 1.45
#       4 threshold = data['residuals'].std() * 1.5
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'y'

# %%
# Out:
#                  DATETIME     SERVER    CPU  CPULOAD  residuals
# 719   2020-03-24 03:30:00  CIHAZ_305  CPU-9     5.67 -25.584491
# 815   2020-03-24 04:00:00  CIHAZ_305  CPU-9     6.03 -26.470866
# 911   2020-03-24 04:30:00  CIHAZ_305  CPU-9     5.26 -26.131398
# 1007  2020-03-24 05:00:00  CIHAZ_305  CPU-9     5.20 -26.634662
# 1295  2020-03-24 06:30:00  CIHAZ_305  CPU-9     6.16 -25.104263
# 2399  2020-03-24 12:15:00  CIHAZ_305  CPU-9    33.78  25.705607
# 2495  2020-03-24 12:45:00  CIHAZ_305  CPU-9    34.84  30.666636
# 2591  2020-03-24 13:15:00  CIHAZ_305  CPU-9    33.55  25.855623
# 2687  2020-03-24 13:45:00  CIHAZ_305  CPU-9    36.58  27.789496
# 2975  2020-03-24 15:15:00  CIHAZ_305  CPU-9    33.13  24.158719
# 3071  2020-03-24 15:45:00  CIHAZ_305  CPU-9    34.51  26.877681
# 3167  2020-03-24 16:15:00  CIHAZ_305  CPU-9    30.31  26.922703
# 3263  2020-03-24 16:45:00  CIHAZ_305  CPU-9    32.10  25.048717
# 3455  2020-03-24 17:45:00  CIHAZ_305  CPU-9    33.99  24.843534
# 4751  2020-03-25 00:30:00  CIHAZ_305  CPU-9     9.92 -24.441473
# 4847  2020-03-25 01:00:00  CIHAZ_305  CPU-9     8.79 -26.946803
# 4943  2020-03-25 01:30:00  CIHAZ_305  CPU-9     7.35 -27.396602
# 5039  2020-03-25 02:00:00  CIHAZ_305  CPU-9     8.09 -27.176356
# 5135  2020-03-25 02:30:00  CIHAZ_305  CPU-9     4.04 -27.415505
# 5327  2020-03-25 03:30:00  CIHAZ_305  CPU-9     6.22 -29.106113
# 5423  2020-03-25 04:00:00  CIHAZ_305  CPU-9     6.05 -29.347430
# 5519  2020-03-25 04:30:00  CIHAZ_305  CPU-9     5.78 -30.859013
# 5615  2020-03-25 05:00:00  CIHAZ_305  CPU-9     4.20 -31.387750
# 5711  2020-03-25 05:30:00  CIHAZ_305  CPU-9     7.81 -28.227931
# 5807  2020-03-25 06:00:00  CIHAZ_305  CPU-9     4.16 -27.740854
# 5903  2020-03-25 06:30:00  CIHAZ_305  CPU-9     7.63 -24.800994
# 5999  2020-03-25 07:00:00  CIHAZ_305  CPU-9     6.46 -29.336621
# 6095  2020-03-25 07:30:00  CIHAZ_305  CPU-9    10.02 -25.855795
# 6287  2020-03-25 08:30:00  CIHAZ_305  CPU-9    10.22 -25.832176

# %%
"""
import matplotlib.pyplot as plt

plt.scatter(filtered_data['DATETIME'], filtered_data['CPULOAD'], color='blue', label='Normal')
plt.scatter(anomalies['DATETIME'], anomalies['CPULOAD'], color='red', label='Anomaly')
plt.xlabel('Tarih')
plt.ylabel('CPULOAD')
plt.title('Nokta Grafiği - Anomaliler')
plt.legend()
plt.show()

"""
